# %% [markdown]
# HKEX Search
#
# Match company names with google knowledge graph api standard entity name.

# %%
import pandas as pd
import json
import urllib
from pprint import pprint

# %%
companies = pd.read_csv('data/companies.csv')

# %%
api_key = "AIzaSyBM6PdtA2iP0ry04W8rCJkgRTk0vm01RfA"

# %%
service_url = 'https://kgsearch.googleapis.com/v1/entities:search'

# %%
clist = []
for query in companies['Stock Name'].iloc[:20].values:
    params = {
        'query': query,
        'limit': 1,
        'indent': True,
        'key': api_key,
    }
    url = service_url + '?' + urllib.parse.urlencode(params)
    response = json.loads(urllib.request.urlopen(url).read())
    clist.append(response['itemListElement'][0]['result']['name'])

# %%
clist
# Out:
# ['Ckh Holdings',
#  'CLP Group',
#  'The Hong Kong and China Gas Company',
#  'The Wharf (Holdings)',
#  'HSBC',
#  'Power Assets Holdings',
#  'Hoifu Energy Group',
#  'PCCW',
#  'Nine Express',
#  'Hang Lung Group',
#  'Hang Seng Bank',
#  'Henderson Land Development',
#  'Hysan Development',
#  'History of Armenia',
#  'Sun Hung Kai Properties',
#  'New World Development',
#  'Oriental Press Group Ltd.',
#  'Swire Pacific',
#  'Wheelock Street Capital L.L.C.',
#  'Frankenstein']

# %%
companies_match = companies[:20].copy()

# %%
companies_match['Match'] = clist

# %%
companies_match
# Out:
#     Stock Code       Stock Name                                Match
# 0            1     CKH HOLDINGS                         Ckh Holdings
# 1            2     CLP HOLDINGS                            CLP Group
# 2            3   HK & CHINA GAS  The Hong Kong and China Gas Company
# 3            4   WHARF HOLDINGS                 The Wharf (Holdings)
# 4            5    HSBC HOLDINGS                                 HSBC
# 5            6     POWER ASSETS                Power Assets Holdings
# 6            7   HK FINANCE INV                   Hoifu Energy Group
# 7            8             PCCW                                 PCCW
# 8            9     NINE EXPRESS                         Nine Express
# 9           10  HANG LUNG GROUP                      Hang Lung Group
# 10          11   HANG SENG BANK                       Hang Seng Bank
# 11          12   HENDERSON LAND           Henderson Land Development
# 12          14        HYSAN DEV                    Hysan Development
# ...

# %%
companies_match = pd.read_csv('data/companies_match.csv')

# %%
companies_match['Stock Code'] = companies_match['Stock Code'].astype(str).str.zfill(4)

# %%
del companies_match['Unnamed: 0']

# %%
companies_match
# Out:
#    Stock Code       Stock Name                                Match
# 0        0001     CKH HOLDINGS                         Ckh Holdings
# 1        0002     CLP HOLDINGS                            CLP Group
# 2        0003   HK & CHINA GAS  The Hong Kong and China Gas Company
# 3        0004   WHARF HOLDINGS                 The Wharf (Holdings)
# 4        0005    HSBC HOLDINGS                                 HSBC
# 5        0006     POWER ASSETS                Power Assets Holdings
# 6        0007   HK FINANCE INV                   Hoifu Energy Group
# 7        0008             PCCW                                 PCCW
# 8        0009     NINE EXPRESS                         Nine Express
# 9        0010  HANG LUNG GROUP                      Hang Lung Group
# 10       0011   HANG SENG BANK                       Hang Seng Bank
# 11       0012   HENDERSON LAND           Henderson Land Development
# 12       0014        HYSAN DEV                    Hysan Development
# ...

# %%
companies_match.to_csv('data/companies_match.csv')
