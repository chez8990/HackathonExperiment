# %% [markdown]
# News API
#
# https://newsapi.org/

# %%
api_key = '2fce71693d12423fadcb8f1871bf7b82'

# %%
import requests
from pprint import pprint
from os import path, getcwd
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
#import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np

# %%
res = requests.get('https://newsapi.org/v2/everything', params = {'q': 'China GDP', 'apiKey':api_key})

# %%
pprint(res.json())
# Out:
# {'articles': [{'author': 'MarketWatch',
#                'content': "BEIJING--China's economy expanded 6.0% in the third "
#                           'quarter from a year earlier, a slower growth pace '
#                           'for a second quarter in a row and hitting the '
#                           "bottom end of Beijing's target range for economic "
#                           'growth this year, official data showed Friday.\r\n'
#                           'It was the sl… [+542 chars]',
#                'description': 'China posts slowest GDP growth rate since 1992 '
#                               "MarketWatch China's economic slowdown deepens, "
#                               'weighing on global growth Dawson Creek Mirror '
#                               'China says its economy grew 6% in the third '
#                               'quarter, slower than expected CNBC Trade war '
#                               "with US: China's GDP growth si…",
# ...

# %%
type(res.json())
# Out:
# dict

# %%
res_json = res.json()

# %%
all_text = '\n'.join([art['description'] for art in res_json['articles']])

# %%
print(all_text)
# Out:
# China posts slowest GDP growth rate since 1992 MarketWatch China's economic slowdown deepens, weighing on global growth Dawson Creek Mirror China says its economy grew 6% in the third quarter, slower than expected CNBC Trade war with US: China's GDP growth si…
# China's economic growth slowed more than expected to 6.0% year-on-year in the third quarter, the weakest pace in at least 27-1/2 years, as demand at home and abroad faltered amid a bruising Sino-U.S. trade war.
# China's economic growth slowed more than expected to 6.0% year-on-year in the third quarter, the weakest pace in at least 27-1/2 years, as demand at home and abroad faltered amid a bruising Sino-U.S. trade war.
# The U.S.-China trade war will cut 2019 global growth to its slowest pace since the 2008-2009 financial crisis, the International Monetary Fund warned on Tuesday, but said output would rebound if their dueling tariffs were removed.
# ...

# %%
# get data directory (using getcwd() is needed to support running example in generated IPython notebook)
d = path.dirname(__file__) if "__file__" in locals() else getcwd()
# lower max_font_size, change the maximum number of word and lighten the background:
circle_mask = np.array(Image.open(path.join(d, "circle.png")))
wordcloud = WordCloud(width=400, height=200, max_font_size=50, max_words=100, background_color="white", stopwords=STOPWORDS, mask=circle_mask).generate(all_text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
#plt.show()
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
circle_mask[100,200]
# Out:
# array([0, 0, 0], dtype=uint8)

# %%
print(STOPWORDS)
# Out:
# {"isn't", 'up', 'himself', 'which', 'my', 'or', "they've", 'as', "won't", 'very', 'no', 'all', 'however', 'else', 'doing', 'who', 'through', 'under', 'and', 'more', "why's", 'could', 'we', 'but', 'me', "you're", 'do', 'in', 'both', 'cannot', "it's", "shouldn't", 'not', 'i', 'until', 'otherwise', 'themselves', "who's", 'a', 'than', 'he', 'from', 'out', 'yourselves', 'your', 'being', 'k', 'why', 'too', 'r', "what's", 'are', 'these', "aren't", 'on', 'after', "hadn't", "we'll", 'shall', "there's", "didn't", 'for', 'it', "shan't", "when's", "he's", 'like', 'did', 'with', 'while', 'between', 'ever', 'what', 'above', 'about', "you'd", 'against', "weren't", 'an', 'few', 'been', 'below', 'by', "i'd", 'should', 'is', 'its', "here's", 'own', "she'd", "hasn't", "they're", 'again', 'the', 'www', 'they', 'since', 'can', "we'd", 'http', 'here', 'into', 'she', 'their', 'same', 'those', "haven't", 'any', 'there', 'only', "that's", 'had', 'most', 'ours', 'his', "wasn't", 'also', "i've", "you've", 'to'
# ...

# %%
# turn the plot into base64 string
from io import BytesIO
import base64

image = BytesIO()
plt.savefig(image, format='png')

# %%
base64.encode

# %%
base64.encodebytes(image.getvalue())
# Out:
# b'
# ...

# %%
# the word cloud part
from os import path, getcwd
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
#import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
from io import BytesIO
import base64

# prepare
# get data directory (using getcwd() is needed to support running example in generated IPython notebook)
d = path.dirname(__file__) if "__file__" in locals() else getcwd()
# lower max_font_size, change the maximum number of word and lighten the background:
circle_mask = np.array(Image.open(path.join(d, "circle.png")))
#
def wordcloud_as_base64(text):
    wordcloud = WordCloud(width=800, height=400, background_color="white", stopwords=STOPWORDS, mask=circle_mask).generate(text)
    plt.figure()
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    #plt.show() # showing the plot destroys it
    # as base64
    image = BytesIO()
    plt.savefig(image, format='png')
    return base64.b64encode(image.getvalue())

# %%
# test it
test_base64 = wordcloud_as_base64(all_text)

# %%
print(test_base64)
# Out:
# b'...'
